# %% [markdown]
# # Comparison Plots for $h=1$, $N=2$ to $10$
#
# 下图分别比较 exact diagonalization 与 QNN/VQE 方法在 $h=1$ 时 $E_0$、$\langle Z \rangle$、$\langle X \rangle$ 的结果。

# %%
import matplotlib.pyplot as plt

# N_list
N_list = np.arange(2, 11)

# Exact Diagonalization (dia)
E0_dia = np.array([-2.236068, -3.493832, -4.756895, -6.025982, -7.292277, -8.560426, -9.825080, -11.088728, -12.355604])
Z_dia = np.array([0.000281, 0.000486, 0.002435, -0.000959, 0.000726, -0.000095, -0.000248, -0.000720, 0.004181])
X_dia = np.array([0.894537, 0.842585, 0.811119, 0.788909, 0.773863, 0.761768, 0.754983, 0.749347, 0.744313])

# QNN/VQE (qnn) 示例数据（如有不同请替换）
E0_qnn = np.array([-2.236068, -3.493959, -4.758770, -6.026674, -7.296230, -8.566772, -9.837951, -11.109566, -12.381490])
Z_qnn = np.array([0.000000, -0.000000, -0.000000, 0.000000, -0.000000, -0.000000, 0.000000, 0.000000, -0.000000])
X_qnn = np.array([0.894427, 0.842363, 0.810095, 0.787732, 0.771145, 0.758264, 0.747924, 0.739408, 0.732255])

plt.figure(figsize=(7,5))
plt.plot(N_list, E0_dia, 'o-', label='Exact Diagonalization')
plt.plot(N_list, E0_qnn, 's--', label='QNN/VQE')
plt.xlabel('System Size N')
plt.ylabel(r'$E_0$')
plt.title(r'Ground State Energy $E_0$ at $h=1$ (J=1)')
plt.legend()
plt.grid(True, ls='--', alpha=0.5)
plt.show()

plt.figure(figsize=(7,5))
plt.plot(N_list, Z_dia, 'o-', label='Exact Diagonalization')
plt.plot(N_list, Z_qnn, 's--', label='QNN/VQE')
plt.xlabel('System Size N')
plt.ylabel(r'$\langle Z \rangle$')
plt.title(r'Magnetization $\langle Z \rangle$ at $h=1$ (J=1)')
plt.legend()
plt.grid(True, ls='--', alpha=0.5)
plt.show()

plt.figure(figsize=(7,5))
plt.plot(N_list, X_dia, 'o-', label='Exact Diagonalization')
plt.plot(N_list, X_qnn, 's--', label='QNN/VQE')
plt.xlabel('System Size N')
plt.ylabel(r'$\langle X \rangle$')
plt.title(r'Magnetization $\langle X \rangle$ at $h=1$ (J=1)')
plt.legend()
plt.grid(True, ls='--', alpha=0.5)
plt.show()
